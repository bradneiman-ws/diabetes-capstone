# %%
from pathlib import Path
import pandas as pd, sqlite3

csv_path = Path("../data/diabetes.csv")
df = pd.read_csv(csv_path)
conn = sqlite3.connect("../data/diabetes.db")
df.to_sql("diabetes_patients", conn, if_exists="replace", index=False)
conn.close()
print("✅ Wrote diabetes_patients to ../data/diabetes.db")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# ✅ Wrote diabetes_patients to ../data/diabetes.db
